# %%
import matplotlib.pyplot as plt

# %%
task_1 = [{'mAP': 0.15,
   'mAP_level_0.85': 0.01,
   'mAP_level_0.5': 0.15,
   'mAP_level_0.55': 0.13,
   'mAP_level_0.6': 0.11,
   'mAP_level_0.7': 0.07,
   'mAP_level_0.8': 0.03,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.09,
   'mAP_level_0.75': 0.05},
  {'mAP_level_0.75': 0.05,
   'mAP': 0.17,
   'mAP_level_0.85': 0.01,
   'mAP_level_0.5': 0.17,
   'mAP_level_0.55': 0.15,
   'mAP_level_0.6': 0.13,
   'mAP_level_0.7': 0.08,
   'mAP_level_0.8': 0.02,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.11},
  {'mAP': 0.27,
   'mAP_level_0.85': 0.02,
   'mAP_level_0.5': 0.27,
   'mAP_level_0.55': 0.24,
   'mAP_level_0.6': 0.21,
   'mAP_level_0.7': 0.13,
   'mAP_level_0.8': 0.05,
   'mAP_level_0.9': 0.01,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.17,
   'mAP_level_0.75': 0.09},
  {'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.24,
   'mAP_level_0.75': 0.13,
   'mAP': 0.35,
   'mAP_level_0.85': 0.04,
   'mAP_level_0.5': 0.35,
   'mAP_level_0.55': 0.32,
   'mAP_level_0.6': 0.28,
   'mAP_level_0.7': 0.18,
   'mAP_level_0.8': 0.08,
   'mAP_level_0.9': 0.01},
  {'mAP_level_0.8': 0.11,
   'mAP_level_0.9': 0.02,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.3,
   'mAP_level_0.75': 0.17,
   'mAP': 0.43,
   'mAP_level_0.85': 0.06,
   'mAP_level_0.5': 0.43,
   'mAP_level_0.55': 0.4,
   'mAP_level_0.6': 0.35,
   'mAP_level_0.7': 0.23},
  {'mAP': 0.49,
   'mAP_level_0.5': 0.49,
   'mAP_level_0.85': 0.08,
   'mAP_level_0.55': 0.46,
   'mAP_level_0.6': 0.41,
   'mAP_level_0.7': 0.29,
   'mAP_level_0.8': 0.14,
   'mAP_level_0.9': 0.03,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.36,
   'mAP_level_0.75': 0.21},
  {'mAP_level_0.75': 0.22,
   'mAP': 0.5,
   'mAP_level_0.5': 0.5,
   'mAP_level_0.85': 0.08,
   'mAP_level_0.55': 0.47,
   'mAP_level_0.6': 0.43,
   'mAP_level_0.7': 0.3,
   'mAP_level_0.8': 0.15,
   'mAP_level_0.9': 0.03,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.37},
  {'mAP': 0.01,
   'mAP_level_0.85': 0.0,
   'mAP_level_0.5': 0.0,
   'mAP_level_0.55': 0.0,
   'mAP_level_0.6': 0.0,
   'mAP_level_0.7': 0.0,
   'mAP_level_0.8': 0.0,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.0,
   'mAP_level_0.75': 0.0},
  {'mAP_level_0.75': 0.01,
   'mAP': 0.04,
   'mAP_level_0.5': 0.04,
   'mAP_level_0.85': 0.0,
   'mAP_level_0.55': 0.03,
   'mAP_level_0.6': 0.03,
   'mAP_level_0.7': 0.02,
   'mAP_level_0.8': 0.01,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.02},
  {'mAP': 0.12,
   'mAP_level_0.5': 0.12,
   'mAP_level_0.85': 0.01,
   'mAP_level_0.55': 0.1,
   'mAP_level_0.6': 0.08,
   'mAP_level_0.7': 0.04,
   'mAP_level_0.8': 0.01,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.06,
   'mAP_level_0.75': 0.03},
  {'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.13,
   'mAP_level_0.75': 0.07,
   'mAP': 0.21,
   'mAP_level_0.85': 0.02,
   'mAP_level_0.5': 0.21,
   'mAP_level_0.55': 0.19,
   'mAP_level_0.6': 0.16,
   'mAP_level_0.7': 0.1,
   'mAP_level_0.8': 0.04,
   'mAP_level_0.9': 0.0},
  {'mAP_level_0.55': 0.24,
   'mAP_level_0.6': 0.21,
   'mAP_level_0.7': 0.13,
   'mAP_level_0.8': 0.06,
   'mAP_level_0.9': 0.01,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.17,
   'mAP_level_0.75': 0.09,
   'mAP': 0.26,
   'mAP_level_0.5': 0.26,
   'mAP_level_0.85': 0.03},
  {'mAP_level_0.75': 0.12,
   'mAP': 0.37,
   'mAP_level_0.5': 0.37,
   'mAP_level_0.85': 0.04,
   'mAP_level_0.55': 0.33,
   'mAP_level_0.6': 0.27,
   'mAP_level_0.7': 0.17,
   'mAP_level_0.8': 0.07,
   'mAP_level_0.9': 0.01,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.22},
  {'mAP_level_0.55': 0.35,
   'mAP_level_0.6': 0.31,
   'mAP_level_0.7': 0.2,
   'mAP_level_0.8': 0.09,
   'mAP_level_0.9': 0.01,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.26,
   'mAP_level_0.75': 0.15,
   'mAP': 0.38,
   'mAP_level_0.5': 0.38,
   'mAP_level_0.85': 0.05},
  {'mAP_level_0.75': 0.16,
   'mAP': 0.41,
   'mAP_level_0.85': 0.05,
   'mAP_level_0.5': 0.41,
   'mAP_level_0.55': 0.38,
   'mAP_level_0.6': 0.34,
   'mAP_level_0.7': 0.22,
   'mAP_level_0.8': 0.1,
   'mAP_level_0.9': 0.01,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.28},
  {'mAP': 0.01,
   'mAP_level_0.85': 0.0,
   'mAP_level_0.5': 0.0,
   'mAP_level_0.55': 0.0,
   'mAP_level_0.6': 0.0,
   'mAP_level_0.7': 0.0,
   'mAP_level_0.8': 0.0,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.0,
   'mAP_level_0.75': 0.0}]

task_2 = [{'mAP_level_0.75': 0.03,
   'mAP': 0.12,
   'mAP_level_0.5': 0.12,
   'mAP_level_0.85': 0.01,
   'mAP_level_0.55': 0.11,
   'mAP_level_0.6': 0.09,
   'mAP_level_0.7': 0.05,
   'mAP_level_0.8': 0.02,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.07},
  {'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.1,
   'mAP_level_0.75': 0.05,
   'mAP': 0.16,
   'mAP_level_0.85': 0.01,
   'mAP_level_0.5': 0.16,
   'mAP_level_0.55': 0.14,
   'mAP_level_0.6': 0.12,
   'mAP_level_0.7': 0.08,
   'mAP_level_0.8': 0.03,
   'mAP_level_0.9': 0.0},
  {'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.15,
   'mAP_level_0.75': 0.08,
   'mAP': 0.23,
   'mAP_level_0.5': 0.23,
   'mAP_level_0.85': 0.02,
   'mAP_level_0.55': 0.21,
   'mAP_level_0.6': 0.19,
   'mAP_level_0.7': 0.12,
   'mAP_level_0.8': 0.05,
   'mAP_level_0.9': 0.0},
  {'mAP_level_0.75': 0.11,
   'mAP': 0.29,
   'mAP_level_0.5': 0.29,
   'mAP_level_0.85': 0.03,
   'mAP_level_0.55': 0.27,
   'mAP_level_0.6': 0.24,
   'mAP_level_0.7': 0.15,
   'mAP_level_0.8': 0.07,
   'mAP_level_0.9': 0.01,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.2},
  {'mAP_level_0.75': 0.14,
   'mAP': 0.38,
   'mAP_level_0.5': 0.38,
   'mAP_level_0.85': 0.04,
   'mAP_level_0.55': 0.35,
   'mAP_level_0.6': 0.31,
   'mAP_level_0.7': 0.2,
   'mAP_level_0.8': 0.09,
   'mAP_level_0.9': 0.01,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.26},
  {'mAP_level_0.8': 0.12,
   'mAP_level_0.9': 0.02,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.32,
   'mAP_level_0.75': 0.19,
   'mAP': 0.46,
   'mAP_level_0.85': 0.06,
   'mAP_level_0.5': 0.46,
   'mAP_level_0.55': 0.43,
   'mAP_level_0.6': 0.38,
   'mAP_level_0.7': 0.26},
  {'mAP': 0.46,
   'mAP_level_0.5': 0.46,
   'mAP_level_0.85': 0.07,
   'mAP_level_0.55': 0.43,
   'mAP_level_0.6': 0.39,
   'mAP_level_0.7': 0.27,
   'mAP_level_0.8': 0.13,
   'mAP_level_0.9': 0.02,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.33,
   'mAP_level_0.75': 0.19},
  {'mAP_level_0.55': 0.0,
   'mAP_level_0.6': 0.0,
   'mAP_level_0.7': 0.0,
   'mAP_level_0.8': 0.0,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.0,
   'mAP_level_0.75': 0.0,
   'mAP': 0.01,
   'mAP_level_0.85': 0.0,
   'mAP_level_0.5': 0.0},
  {'mAP_level_0.8': 0.0,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.02,
   'mAP_level_0.75': 0.01,
   'mAP': 0.03,
   'mAP_level_0.85': 0.0,
   'mAP_level_0.5': 0.03,
   'mAP_level_0.55': 0.03,
   'mAP_level_0.6': 0.02,
   'mAP_level_0.7': 0.01},
  {'mAP_level_0.55': 0.07,
   'mAP_level_0.6': 0.06,
   'mAP_level_0.7': 0.04,
   'mAP_level_0.8': 0.02,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.05,
   'mAP_level_0.75': 0.03,
   'mAP': 0.08,
   'mAP_level_0.5': 0.08,
   'mAP_level_0.85': 0.01},
  {'mAP_level_0.75': 0.07,
   'mAP': 0.16,
   'mAP_level_0.85': 0.02,
   'mAP_level_0.5': 0.16,
   'mAP_level_0.55': 0.15,
   'mAP_level_0.6': 0.14,
   'mAP_level_0.7': 0.1,
   'mAP_level_0.8': 0.05,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.12},
  {'mAP_level_0.75': 0.1,
   'mAP': 0.2,
   'mAP_level_0.5': 0.2,
   'mAP_level_0.85': 0.04,
   'mAP_level_0.55': 0.18,
   'mAP_level_0.6': 0.17,
   'mAP_level_0.7': 0.13,
   'mAP_level_0.8': 0.07,
   'mAP_level_0.9': 0.01,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.15},
  {'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.25,
   'mAP_level_0.75': 0.17,
   'mAP': 0.31,
   'mAP_level_0.85': 0.07,
   'mAP_level_0.5': 0.31,
   'mAP_level_0.55': 0.3,
   'mAP_level_0.6': 0.28,
   'mAP_level_0.7': 0.21,
   'mAP_level_0.8': 0.12,
   'mAP_level_0.9': 0.03},
  {'mAP': 0.35,
   'mAP_level_0.5': 0.35,
   'mAP_level_0.85': 0.09,
   'mAP_level_0.55': 0.33,
   'mAP_level_0.6': 0.31,
   'mAP_level_0.7': 0.24,
   'mAP_level_0.8': 0.14,
   'mAP_level_0.9': 0.03,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.28,
   'mAP_level_0.75': 0.2},
  {'mAP': 0.37,
   'mAP_level_0.85': 0.1,
   'mAP_level_0.5': 0.37,
   'mAP_level_0.55': 0.35,
   'mAP_level_0.6': 0.33,
   'mAP_level_0.7': 0.26,
   'mAP_level_0.8': 0.16,
   'mAP_level_0.9': 0.04,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.3,
   'mAP_level_0.75': 0.21},
  {'mAP_level_0.55': 0.0,
   'mAP_level_0.6': 0.0,
   'mAP_level_0.7': 0.0,
   'mAP_level_0.8': 0.0,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.0,
   'mAP_level_0.75': 0.0,
   'mAP': 0.01,
   'mAP_level_0.85': 0.0,
   'mAP_level_0.5': 0.0}]
task_3 = [{'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.0,
   'mAP_level_0.75': 0.0,
   'mAP': 0.01,
   'mAP_level_0.5': 0.01,
   'mAP_level_0.85': 0.0,
   'mAP_level_0.55': 0.01,
   'mAP_level_0.6': 0.01,
   'mAP_level_0.7': 0.0,
   'mAP_level_0.8': 0.0,
   'mAP_level_0.9': 0.0},
  {'mAP_level_0.75': 0.0,
   'mAP': 0.05,
   'mAP_level_0.5': 0.05,
   'mAP_level_0.85': 0.0,
   'mAP_level_0.55': 0.04,
   'mAP_level_0.6': 0.02,
   'mAP_level_0.7': 0.01,
   'mAP_level_0.8': 0.0,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.01},
  {'mAP_level_0.75': 0.01,
   'mAP': 0.09,
   'mAP_level_0.5': 0.09,
   'mAP_level_0.85': 0.0,
   'mAP_level_0.55': 0.07,
   'mAP_level_0.6': 0.05,
   'mAP_level_0.7': 0.02,
   'mAP_level_0.8': 0.01,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.04},
  {'mAP_level_0.75': 0.03,
   'mAP': 0.13,
   'mAP_level_0.85': 0.0,
   'mAP_level_0.5': 0.13,
   'mAP_level_0.55': 0.11,
   'mAP_level_0.6': 0.09,
   'mAP_level_0.7': 0.04,
   'mAP_level_0.8': 0.01,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.06},
  {'mAP_level_0.75': 0.04,
   'mAP': 0.19,
   'mAP_level_0.5': 0.19,
   'mAP_level_0.85': 0.0,
   'mAP_level_0.55': 0.16,
   'mAP_level_0.6': 0.12,
   'mAP_level_0.7': 0.06,
   'mAP_level_0.8': 0.01,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.09},
  {'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.11,
   'mAP_level_0.75': 0.03,
   'mAP': 0.24,
   'mAP_level_0.5': 0.24,
   'mAP_level_0.85': 0.0,
   'mAP_level_0.55': 0.2,
   'mAP_level_0.6': 0.16,
   'mAP_level_0.7': 0.07,
   'mAP_level_0.8': 0.01,
   'mAP_level_0.9': 0.0},
  {'mAP': 0.33,
   'mAP_level_0.85': 0.01,
   'mAP_level_0.5': 0.33,
   'mAP_level_0.55': 0.3,
   'mAP_level_0.6': 0.24,
   'mAP_level_0.7': 0.12,
   'mAP_level_0.8': 0.03,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.18,
   'mAP_level_0.75': 0.06},
  {'mAP_level_0.75': 0.0,
   'mAP': 0.01,
   'mAP_level_0.85': 0.0,
   'mAP_level_0.5': 0.0,
   'mAP_level_0.55': 0.0,
   'mAP_level_0.6': 0.0,
   'mAP_level_0.7': 0.0,
   'mAP_level_0.8': 0.0,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.0},
  {'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.09,
   'mAP_level_0.75': 0.05,
   'mAP': 0.12,
   'mAP_level_0.85': 0.02,
   'mAP_level_0.5': 0.12,
   'mAP_level_0.55': 0.11,
   'mAP_level_0.6': 0.1,
   'mAP_level_0.7': 0.07,
   'mAP_level_0.8': 0.04,
   'mAP_level_0.9': 0.01},
  {'mAP_level_0.55': 0.14,
   'mAP_level_0.6': 0.13,
   'mAP_level_0.7': 0.1,
   'mAP_level_0.8': 0.07,
   'mAP_level_0.9': 0.02,
   'mAP_level_0.95': 0.01,
   'mAP_level_0.65': 0.12,
   'mAP_level_0.75': 0.09,
   'mAP': 0.15,
   'mAP_level_0.85': 0.05,
   'mAP_level_0.5': 0.15},
  {'mAP': 0.18,
   'mAP_level_0.85': 0.06,
   'mAP_level_0.5': 0.18,
   'mAP_level_0.55': 0.17,
   'mAP_level_0.6': 0.16,
   'mAP_level_0.7': 0.12,
   'mAP_level_0.8': 0.08,
   'mAP_level_0.9': 0.03,
   'mAP_level_0.95': 0.01,
   'mAP_level_0.65': 0.14,
   'mAP_level_0.75': 0.1},
  {'mAP_level_0.75': 0.12,
   'mAP': 0.22,
   'mAP_level_0.85': 0.07,
   'mAP_level_0.5': 0.22,
   'mAP_level_0.55': 0.2,
   'mAP_level_0.6': 0.19,
   'mAP_level_0.7': 0.14,
   'mAP_level_0.8': 0.1,
   'mAP_level_0.9': 0.03,
   'mAP_level_0.95': 0.01,
   'mAP_level_0.65': 0.16},
  {'mAP_level_0.75': 0.15,
   'mAP': 0.25,
   'mAP_level_0.85': 0.09,
   'mAP_level_0.5': 0.25,
   'mAP_level_0.55': 0.23,
   'mAP_level_0.6': 0.22,
   'mAP_level_0.7': 0.17,
   'mAP_level_0.8': 0.12,
   'mAP_level_0.9': 0.05,
   'mAP_level_0.95': 0.01,
   'mAP_level_0.65': 0.2},
  {'mAP_level_0.75': 0.0,
   'mAP': 0.01,
   'mAP_level_0.5': 0.0,
   'mAP_level_0.85': 0.0,
   'mAP_level_0.55': 0.0,
   'mAP_level_0.6': 0.0,
   'mAP_level_0.7': 0.0,
   'mAP_level_0.8': 0.0,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.0},
  {'mAP_level_0.75': 0.19,
   'mAP': 0.32,
   'mAP_level_0.85': 0.11,
   'mAP_level_0.5': 0.32,
   'mAP_level_0.55': 0.3,
   'mAP_level_0.6': 0.28,
   'mAP_level_0.7': 0.23,
   'mAP_level_0.8': 0.16,
   'mAP_level_0.9': 0.06,
   'mAP_level_0.95': 0.01,
   'mAP_level_0.65': 0.26},
  {'mAP_level_0.75': 0.0,
   'mAP': 0.01,
   'mAP_level_0.85': 0.0,
   'mAP_level_0.5': 0.0,
   'mAP_level_0.55': 0.0,
   'mAP_level_0.6': 0.0,
   'mAP_level_0.7': 0.0,
   'mAP_level_0.8': 0.0,
   'mAP_level_0.9': 0.0,
   'mAP_level_0.95': 0.0,
   'mAP_level_0.65': 0.0}]

# %%
baseline_base_1 = [0.1, 0.14, 0.2, 0.23, 0.31, 0.42, 0.54, 0.59]
baseline_adapt_1 = [0.05, 0.09, 0.14, 0.18, 0.24, 0.35, 0.47, 0.52]

previous_1_base = [0.2, 0.24, 0.3, 0.36, 0.4, 0.46, 0.51, 0.56]
previous_1_adapt = [0.21, 0.27, 0.34, 0.37, 0.4, 0.44, 0.47, 0.49]

baseline_base_2 = [0.07, 0.11, 0.15, 0.2, 0.29, 0.4, 0.53, 0.56]
baseline_adapt_2 = [0.04, 0.07, 0.1, 0.12, 0.24, 0.31, 0.39, 0.42]

previous_2_base = [0.18, 0.23, 0.28, 0.33, 0.38, 0.43, 0.46, 0.52]
previous_2_adapt = [0.11, 0.15, 0.17, 0.18, 0.29, 0.33, 0.35, 0.4]

baseline_base_3 = [0.03, 0.07, 0.09, 0.12, 0.17, 0.2, 0.28, 0.37]
baseline_adapt_3 = [0.11, 0.15, 0.19, 0.23, 0.26, 0.29, 0.32, 0.35]

previous_3_base = [0.02, 0.1, 0.14, 0.17, 0.21, 0.26, 0.31, 0.35]
previous_3_adapt = [0.14, 0.16, 0.17, 0.19, 0.23, 0.26, 0.28, 0.32]

# %%
task_1_maps_base = [x['mAP'] for x in task_1[:len(task_1)//2]]
task_1_maps_adapt = [x['mAP'] for x in task_1[len(task_1)//2:]]

# %%
task_1_maps_base

# %%
task_1_maps_adapt

# %%
plt.plot(task_1_maps_base, label='Eval')
plt.plot(previous_1_base, label='Previous Eval')
plt.plot(baseline_base_1, label='Baseline')
plt.title('Task 1 base')
plt.legend()

# %%
plt.plot(task_1_maps_adapt, label='Eval')
plt.plot(previous_1_adapt, label='Previous Eval')
plt.plot(baseline_adapt_1, label='Baseline')
plt.title('Task 1 adapt')
plt.legend()

# %%
task_2_maps_base = [x['mAP'] for x in task_2[:len(task_2)//2]]
task_2_maps_adapt = [x['mAP'] for x in task_2[len(task_2)//2:]]

# %%
plt.plot(task_2_maps_base, label='Eval')
plt.plot(previous_2_base, label='Previous Eval')
plt.plot(baseline_base_2, label='Baseline')
plt.title('Task 2 base')
plt.legend()

# %%
plt.plot(task_2_maps_adapt, label='Eval')
plt.plot(previous_2_adapt, label='Previous Eval')
plt.plot(baseline_adapt_2, label='Baseline')
plt.title('Task 2 adapt')
plt.legend()

# %%
task_3_maps_base = [x['mAP'] for x in task_3[:len(task_3)//2]]
task_3_maps_adapt = [x['mAP'] for x in task_3[len(task_3)//2:]]

# %%
plt.plot(task_3_maps_base, label='Eval')
plt.plot(previous_3_base, label='Previous Eval')
plt.plot(baseline_base_3, label='Baseline')
plt.title('Task 3 base')
plt.legend()

# %%
plt.plot(task_3_maps_adapt, label='Eval')
plt.plot(previous_3_adapt, label='Previous Eval')
plt.plot(baseline_adapt_3, label='Baseline')
plt.title('Task 3 adapt')
plt.legend()

# %%
im.show()

# %%
im.size

# %%
im = im.resize((224, 224))

# %%
im.size

# %%
asarray(im).shape

# %%
im = moveaxis(asarray(im), 2, 0)
im = moveaxis(asarray(im), 0, 2)

# %%
im.shape

# %%
im_tensor = torch.from_numpy(im)

# %%
im_tensor.unsqueeze(dim=-1)

# %%
im_tensor.shape

# %%
torch.from_numpy(asarray(im)).unsqueeze(dim=-1).shape

# %%
single_image = sup_model(torch.from_numpy(asarray(im)).unsqueeze(dim=-1))

# %%
single_image.shape

# %%
single_image = single_image.unsqueeze(dim=-1)

# %%
single_image.shape

# %%
sup_model(single_image)

# %%
torch.nn.functional.interpolate(single_image, (224, 224))

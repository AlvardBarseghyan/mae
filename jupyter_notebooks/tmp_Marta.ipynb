# %%
import numpy as np

# %%
data = np.load('../annotations/cs_train.npy', allow_pickle=True).item()

# %%
data.keys()
# Out:
# dict_keys(['images', 'annotations', 'categories'])

# %%
data['images'][0]
# Out:
# {'file_name': '/mnt/lwll/lwll-coral/hrant/leftImg8bit/train/krefeld/krefeld_000000_011655_leftImg8bit.png',
#  'height': 1024,
#  'width': 2048,
#  'id': 0,
#  'black_image': array([[3, 3, 3, ..., 3, 3, 3],
#         [3, 3, 3, ..., 3, 3, 3],
#         [3, 3, 3, ..., 3, 3, 3],
#         ...,
#         [3, 3, 3, ..., 3, 3, 3],
#         [3, 3, 3, ..., 3, 3, 3],
#         [3, 3, 3, ..., 3, 3, 3]], dtype=uint8),
#  'patch_labels': array([11, 11, 11, 23, 23, 23, 23, 23, 11, 11, 11, 11, 11, 11, 11, 11, 11,
#         11, 11, 23, 23, 23, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11,
#         23, 11, 11, 11, 11, 11, 11, 11, 11,  4, 11, 11, 11, 11, 23, 11, 11,
#         11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11,
#         11, 11, 11, 11, 11, 11, 11, 19, 28,  4, 11, 11, 24, 11, 11, 11, 17,
#          8,  8,  8,  8,  7,  7,  7,  7,  7,  8,  8,  8,  8,  8,  7,  7,  7,
#          7,  7,  7,  7,  7,  7,  7,  8,  8,  8,  7,  7,  7,  7,  7,  7,  7,
# ...

# %%
tmp = '/mnt/lwll/lwll-coral/hrant/leftImg8bit/train/'
[data['images'][i]['file_name'].replace(tmp, '') for i in range(len(data['images']))]
# Out:
# ['krefeld/krefeld_000000_011655_leftImg8bit.png',
#  'krefeld/krefeld_000000_012353_leftImg8bit.png',
#  'krefeld/krefeld_000000_024276_leftImg8bit.png',
#  'krefeld/krefeld_000000_006274_leftImg8bit.png',
#  'dusseldorf/dusseldorf_000093_000019_leftImg8bit.png',
#  'dusseldorf/dusseldorf_000177_000019_leftImg8bit.png',
#  'dusseldorf/dusseldorf_000020_000019_leftImg8bit.png',
#  'dusseldorf/dusseldorf_000022_000019_leftImg8bit.png',
#  'hamburg/hamburg_000000_053086_leftImg8bit.png',
#  'hamburg/hamburg_000000_089696_leftImg8bit.png',
#  'hamburg/hamburg_000000_032906_leftImg8bit.png',
#  'hamburg/hamburg_000000_065983_leftImg8bit.png',
#  'bremen/bremen_000233_000019_leftImg8bit.png',
#  'bremen/bremen_000161_000019_leftImg8bit.png',
#  'bremen/bremen_000182_000019_leftImg8bit.png',
#  'bremen/bremen_000126_000019_leftImg8bit.png',
#  'ulm/ulm_000054_000019_leftImg8bit.png',
#  'ulm/ulm_000040_000019_leftImg8bit.png',
#  'ulm/ulm_000064_000019_leftImg8bit.png',
# ...

# %%
data['images'][0]['patch_labels'].shape
# Out:
# (196,)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(data['images'][0]['black_image']);

# %%
from matplotlib.image import imread

# %%
plt.imshow(imread(data['images'][0]['file_name']));

# %%
dct = {}

dct['images']
